# %% [markdown]
# <a href="https://colab.research.google.com/github/25040150-source/PROBABILIDAD-Y-ESTADISTICA/blob/main/UNIDAD%201/PRACTICA2PYE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**PROBABILIDAD Y ESTADISTICA**
# #GRUPO 2Y
# UNIDAD 1
#
# MAESTRO:JOSE GABRIEL RODIGUEZ RIVAS
#
# ALUMNA:MARCELA PEREZ GURROLA
#
# PRACTICA 2: MAXIMO, MINIMO, DISPERSION DE LOS DATOS

# %%
from statistics import*
import random
import matplotlib.pyplot as plt

# %%
fabrica1=[]
for i in range(100):
  numero_aleatorio=round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [74.87, 99.56, 52.84, 84.89, 81.91, 64.65, 71.91, 62.89, 66.73, 74.48, 88.28, 50.63, 71.78, 60.61, 77.04, 82.0, 62.22, 60.58, 68.82, 74.4, 65.53, 99.13, 80.78, 88.28, 92.97, 66.29, 52.61, 89.47, 70.99, 77.63, 67.32, 69.22, 57.01, 96.09, 70.32, 93.84, 83.23, 60.23, 73.89, 70.49, 97.49, 81.31, 68.47, 87.14, 88.86, 77.04, 83.97, 78.54, 89.42, 50.1, 62.07, 68.84, 77.4, 88.59, 89.8, 52.73, 60.51, 80.18, 52.81, 60.68, 79.16, 72.28, 88.81, 80.84, 52.14, 80.63, 75.76, 88.26, 69.88, 66.13, 66.07, 93.09, 53.24, 79.73, 54.26, 86.63, 58.75, 51.97, 88.57, 71.77, 65.64, 80.87, 77.55, 81.19, 50.58, 59.59, 81.83, 88.57, 94.43, 52.21, 51.9, 86.23, 65.67, 85.68, 97.61, 68.12, 69.03, 79.91, 53.63, 60.27]

# %%
fabrica2=[]
for i in range(100):
  numero_aleatorio2=round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [87.52, 45.87, 72.86, 65.98, 42.41, 71.35, 58.75, 74.05, 50.4, 82.15, 86.73, 62.17, 82.34, 41.87, 74.93, 43.79, 67.44, 72.75, 55.96, 59.2, 59.92, 68.51, 41.04, 92.58, 86.91, 80.66, 56.96, 80.57, 50.48, 54.02, 82.69, 85.1, 83.64, 43.91, 72.38, 55.18, 71.07, 69.22, 89.08, 89.01, 46.19, 41.76, 45.8, 58.34, 82.54, 87.16, 89.99, 90.43, 45.65, 47.91, 58.14, 76.92, 88.67, 88.11, 87.06, 84.32, 76.46, 60.12, 60.39, 41.15, 74.68, 78.5, 86.76, 75.01, 85.09, 46.34, 74.96, 45.79, 46.37, 62.37, 88.7, 71.26, 79.2, 47.31, 78.97, 46.82, 79.87, 72.18, 47.35, 80.43, 88.88, 59.97, 46.92, 67.84, 47.53, 82.73, 77.25, 69.64, 92.91, 92.88, 89.81, 43.82, 55.31, 81.91, 67.48, 86.33, 84.06, 44.41, 90.13, 49.43]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
print("ESTADISTICA DESCRIPTIVA DE LA FABRICA 1\n","Media= ",media1,
"\n Mediana= ",mediana1,"\n Moda= ",moda1, "\n Maximo= ",maximo1,
"\n Minimo= ",minimo1, "\n Rango= ",rango1)
# Out:
# ESTADISTICA DESCRIPTIVA DE LA FABRICA 1
#  Media=  73.6084
#  Mediana=  74.14500000000001
#  Moda=  88.28
#  Maximo=  99.56
#  Minimo=  50.1
#  Rango=  49.46

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
print("ESTADISTICA DESCRIPTIVA DE LA FABRICA 2\n","Media= ",media2,
"\n Mediana= ",mediana2,"\n Moda= ",moda2, "\n Maximo= ",maximo2,
"\n Minimo= ",minimo2, "\n Rango= ",rango2)
# Out:
# ESTADISTICA DESCRIPTIVA DE LA FABRICA 2
#  Media=  67.9563
#  Mediana=  67.475
#  Moda=  56.86
#  Maximo=  92.73
#  Minimo=  40.94
#  Rango=  51.790000000000006

# %%
desviacion_estandar_fabrica1=stdev(fabrica1)
print(desviacion_estandar_fabrica1)
# Out:
# 13.524898679207482

# %%
desviacion_estandar_fabrica2=stdev(fabrica2)
print(desviacion_estandar_fabrica2)
# Out:
# 16.565033888198712

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media1,color='b',linestyle='dashed',linewidth=2,label=f'media=(media1:.2f)')
plt.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label=f'mediana=(mediana1:.2f)')
plt.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label=f'moda=(moda1:.2f)')
plt.axvline(media1-desviacion_estandar_fabrica1,color='black',linestyle='dashed',
linewidth=2,label=f'Desv. Estandar=(desviación_estandar_fabrica1:.2f)')
plt.axvline(media1+desviacion_estandar_fabrica1,color='black',linestyle='dashed',
linewidth=2,label=f'Desv. Estandar=(desviación_estandar_fabrica1:.2f)')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('PRODUCCION DE LA FABRICA 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media2,color='b',linestyle='dashed',linewidth=2,label=f'media=(media2:.2f)')
plt.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label=f'mediana=(mediana2:.2f)')
plt.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label=f'moda=(moda2:.2f)')
plt.axvline(media2-desviacion_estandar_fabrica2,color='black',linestyle='dashed',
linewidth=2,label=f'Desv. Estandar=(desviación_estandar_fabrica2:.2f)')
plt.axvline(media2+desviacion_estandar_fabrica2,color='black',linestyle='dashed',
linewidth=2,label=f'Desv. Estandar=(desviación_estandar_fabrica2:.2f)')
plt.xlabel('valor')
plt.ylabel('frecuencia')
plt.title('PRODUCCION DE LA FABRICA 2')
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
#la densidad grafica es una forma devisualizar ladistribucion de datos en un
#intervalo o periodo de tiempos continuos
#se basa en un histograma que usa el suavizado de kernel para trazar valores
#lo que permite obtener distribuciones mas suaves al reducir el ruido
#una curv de densidad muestra la ubicacion de la media y la mediana de una distribución
sns.histplot(x=fabrica1,kde=True,kde_kws={'bw_adjust':0.5 },bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x=fabrica2,kde=True,kde_kws={'bw_adjust':0.5 },bins=10)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# <a href="https://colab.research.google.com/github/25040150-source/PROBABILIDAD-Y-ESTADISTICA/blob/main/UNIDAD%201/PRACTICA3_PYE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PROBABILIDAD Y ESTADISTICA**
# ##GRUPO 2Y
# ##UNIDAD 1
#
# ####MAESTRO:JOSE GABRIEL RODIGUEZ RIVAS
#
# ####ALUMNA:MARCELA PEREZ GURROLA
#
# #####PRACTICA 3:Tabla de frecuencias y regla de Sturges.

# %%
#basado en el libro estadistica para administracion pagina 12
#creamos una lista vacia que representa la edad de 100 personas
import random
edades=[]
#hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for a in range(100):
  #generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  #numero_aleatorio
    numero_aleatorio=(random.randint(18,70))
    #agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [24, 49, 35, 36, 25, 27, 38, 49, 28, 56, 26, 61, 67, 58, 66, 63, 38, 64, 58, 19, 60, 57, 55, 66, 57, 42, 55, 40, 54, 44, 49, 61, 50, 67, 51, 29, 44, 51, 51, 46, 19, 39, 49, 58, 60, 57, 27, 55, 31, 23, 57, 27, 40, 18, 56, 38, 62, 63, 43, 29, 22, 39, 26, 67, 65, 51, 68, 31, 29, 47, 25, 52, 39, 37, 18, 25, 39, 36, 69, 70, 45, 22, 68, 42, 18, 51, 19, 38, 61, 52, 36, 51, 32, 21, 48, 19, 69, 36, 19, 26]

# %%
import pandas as pd
#creamos un DataFrame de pandas con los numeros aleatorios
df=pd.DataFrame(edades,columns=['edad'])
df.head()
# Out:
#    edad
# 0    24
# 1    49
# 2    35
# 3    36
# 4    25

# %%
#calculamos la tabla de distribucion de frecuencias
tabla_frecuencias=df['edad'].value_counts().reset_index()
tabla_frecuencias.columns=['edad','frecuencia']
tabla_frecuencias=tabla_frecuencias.sort_values(by='edad')
#imprimir la tabla de distribucion de frecuencias
print("TABLA DE DISTRIBUCION DE FRECUENCIAS:")
tabla_frecuencias
# Out:
# TABLA DE DISTRIBUCION DE FRECUENCIAS:
#     edad  frecuencia
# 14    18           3
# 1     19           5
# 44    21           1
# 24    22           2
# 37    23           1
# 28    24           1
# 13    25           3
# 12    26           3
# 11    27           3
# 30    28           1
# 15    29           3
# 22    31           2
# 43    32           1
# 29    35           1
# 5     36           4
# 40    37           1
# 2     38           4
# 3     39           4
# 19    40           2
# 21    42           2
# 36    43           1
# 25    44           2
# 42    45           1
# 34    46           1
# 38    47           1
# 45    48           1
# 4     49           4
# 31    50           1
# 0     51           6
# 26    52           2
# 32    54           1
# 9     55           3
# 18    56           2
# 6     57           4
# 10    58           3
# 20    60           2
# 7     61           3
# 35    62           1
# 27    63           2
# 33    64           1
# 39    65           1
# 17    66           2
# 8     67           3
# 23    68           2
# 16    69           2
# 41    70           1

# %%
tabla_frecuencias['frec relativa']=tabla_frecuencias['frecuencia']/100
tabla_frecuencias
# Out:
#     edad  frecuencia  frec relativa
# 14    18           3           0.03
# 1     19           5           0.05
# 44    21           1           0.01
# 24    22           2           0.02
# 37    23           1           0.01
# 28    24           1           0.01
# 13    25           3           0.03
# 12    26           3           0.03
# 11    27           3           0.03
# 30    28           1           0.01
# 15    29           3           0.03
# 22    31           2           0.02
# 43    32           1           0.01
# 29    35           1           0.01
# 5     36           4           0.04
# 40    37           1           0.01
# 2     38           4           0.04
# 3     39           4           0.04
# 19    40           2           0.02
# 21    42           2           0.02
# 36    43           1           0.01
# 25    44           2           0.02
# 42    45           1           0.01
# 34    46           1           0.01
# 38    47           1           0.01
# 45    48           1           0.01
# 4     49           4           0.04
# 31    50           1           0.01
# 0     51           6           0.06
# 26    52           2           0.02
# 32    54           1           0.01
# 9     55           3           0.03
# 18    56           2           0.02
# 6     57           4           0.04
# 10    58           3           0.03
# 20    60           2           0.02
# 7     61           3           0.03
# 35    62           1           0.01
# 27    63           2           0.02
# 33    64           1           0.01
# 39    65           1           0.01
# 17    66           2           0.02
# 8     67           3           0.03
# 23    68           2           0.02
# 16    69           2           0.02
# 41    70           1           0.01

# %%
tabla_frecuencias['frec porcentual']=tabla_frecuencias['frecuencia']/100*100
tabla_frecuencias
# Out:
#     edad  frecuencia  frec relativa  frec porcentual
# 14    18           3           0.03              3.0
# 1     19           5           0.05              5.0
# 44    21           1           0.01              1.0
# 24    22           2           0.02              2.0
# 37    23           1           0.01              1.0
# 28    24           1           0.01              1.0
# 13    25           3           0.03              3.0
# 12    26           3           0.03              3.0
# 11    27           3           0.03              3.0
# 30    28           1           0.01              1.0
# 15    29           3           0.03              3.0
# 22    31           2           0.02              2.0
# 43    32           1           0.01              1.0
# 29    35           1           0.01              1.0
# 5     36           4           0.04              4.0
# 40    37           1           0.01              1.0
# 2     38           4           0.04              4.0
# 3     39           4           0.04              4.0
# 19    40           2           0.02              2.0
# 21    42           2           0.02              2.0
# 36    43           1           0.01              1.0
# 25    44           2           0.02              2.0
# 42    45           1           0.01              1.0
# 34    46           1           0.01              1.0
# 38    47           1           0.01              1.0
# 45    48           1           0.01              1.0
# 4     49           4           0.04              4.0
# 31    50           1           0.01              1.0
# 0     51           6           0.06              6.0
# 26    52           2           0.02              2.0
# 32    54           1           0.01              1.0
# 9     55           3           0.03              3.0
# 18    56           2           0.02              2.0
# 6     57           4           0.04              4.0
# 10    58           3           0.03              3.0
# 20    60           2           0.02              2.0
# 7     61           3           0.03              3.0
# 35    62           1           0.01              1.0
# 27    63           2           0.02              2.0
# 33    64           1           0.01              1.0
# 39    65           1           0.01              1.0
# 17    66           2           0.02              2.0
# 8     67           3           0.03              3.0
# 23    68           2           0.02              2.0
# 16    69           2           0.02              2.0
# 41    70           1           0.01              1.0

# %%
tabla_frecuencias['frec acumulada']=tabla_frecuencias['frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     edad  frecuencia  frec relativa  frec porcentual  frec acumulada
# 14    18           3           0.03              3.0               3
# 1     19           5           0.05              5.0               8
# 44    21           1           0.01              1.0               9
# 24    22           2           0.02              2.0              11
# 37    23           1           0.01              1.0              12
# 28    24           1           0.01              1.0              13
# 13    25           3           0.03              3.0              16
# 12    26           3           0.03              3.0              19
# 11    27           3           0.03              3.0              22
# 30    28           1           0.01              1.0              23
# 15    29           3           0.03              3.0              26
# 22    31           2           0.02              2.0              28
# 43    32           1           0.01              1.0              29
# 29    35           1           0.01              1.0              30
# 5     36           4           0.04              4.0              34
# 40    37           1           0.01              1.0              35
# 2     38           4           0.04              4.0              39
# 3     39           4           0.04              4.0              43
# 19    40           2           0.02              2.0              45
# 21    42           2           0.02              2.0              47
# 36    43           1           0.01              1.0              48
# 25    44           2           0.02              2.0              50
# 42    45           1           0.01              1.0              51
# 34    46           1           0.01              1.0              52
# 38    47           1           0.01              1.0              53
# 45    48           1           0.01              1.0              54
# 4     49           4           0.04              4.0              58
# 31    50           1           0.01              1.0              59
# 0     51           6           0.06              6.0              65
# 26    52           2           0.02              2.0              67
# 32    54           1           0.01              1.0              68
# 9     55           3           0.03              3.0              71
# 18    56           2           0.02              2.0              73
# 6     57           4           0.04              4.0              77
# 10    58           3           0.03              3.0              80
# 20    60           2           0.02              2.0              82
# 7     61           3           0.03              3.0              85
# 35    62           1           0.01              1.0              86
# 27    63           2           0.02              2.0              88
# 33    64           1           0.01              1.0              89
# 39    65           1           0.01              1.0              90
# 17    66           2           0.02              2.0              92
# 8     67           3           0.03              3.0              95
# 23    68           2           0.02              2.0              97
# 16    69           2           0.02              2.0              99
# 41    70           1           0.01              1.0             100

# %%
#importamos la libreria math de funciones matematicas
import math

# %%
#volvemos a usar la lista de edades
print(edades)
# Out:
# [24, 49, 35, 36, 25, 27, 38, 49, 28, 56, 26, 61, 67, 58, 66, 63, 38, 64, 58, 19, 60, 57, 55, 66, 57, 42, 55, 40, 54, 44, 49, 61, 50, 67, 51, 29, 44, 51, 51, 46, 19, 39, 49, 58, 60, 57, 27, 55, 31, 23, 57, 27, 40, 18, 56, 38, 62, 63, 43, 29, 22, 39, 26, 67, 65, 51, 68, 31, 29, 47, 25, 52, 39, 37, 18, 25, 39, 36, 69, 70, 45, 22, 68, 42, 18, 51, 19, 38, 61, 52, 36, 51, 32, 21, 48, 19, 69, 36, 19, 26]

# %%
#creamos un DataFrame con las edades
df=pd.DataFrame({'edad':edades})
df
# Out:
#     edad
# 0     24
# 1     49
# 2     35
# 3     36
# 4     25
# ..   ...
# 95    19
# 96    69
# 97    36
# 98    19
# 99    26
#
# [100 rows x 1 columns]

# %%
#calcular el numero de intervalos utilizando la regla de Sturges
n=len(edades)
K=int(1+math.log2(n))
print("valor de n= ",n,"\nNumero de intervalos= ",K)
# Out:
# valor de n=  100
# Numero de intervalos=  7

# %%
#crear la tabla de frecuencias
tabla_frecuencias=pd.cut(df['edad'],bins=K,include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns=['clase','frec']
tabla_frecuencias
# Out:
#               clase  frec
# 0  (47.714, 55.143]    18
# 1  (32.857, 40.286]    16
# 2  (17.947, 25.429]    16
# 3  (55.143, 62.571]    15
# 4    (62.571, 70.0]    14
# 5  (25.429, 32.857]    13
# 6  (40.286, 47.714]     8

# %%
#ordenamos la tabla de frecuencias por el intervalo
tabla_frecuencias=tabla_frecuencias.sort_values(by='clase')
tabla_frecuencias
# Out:
#               clase  frec
# 2  (17.947, 25.429]    16
# 5  (25.429, 32.857]    13
# 1  (32.857, 40.286]    16
# 6  (40.286, 47.714]     8
# 0  (47.714, 55.143]    18
# 3  (55.143, 62.571]    15
# 4    (62.571, 70.0]    14

# %%
#generamos las siguientes columnas
tabla_frecuencias['frec Rel']=tabla_frecuencias['frec']/n
tabla_frecuencias['frec Porc']=tabla_frecuencias['frec']/n*100
tabla_frecuencias['frec Ac']=tabla_frecuencias['frec'].cumsum()
tabla_frecuencias['frec Porc Ac']=tabla_frecuencias['frec'].cumsum()
#mostramos la tabla de frecuencia
print(tabla_frecuencias)
# Out:
#               clase  frec  frec Rel  frec Porc  frec Ac  frec Porc Ac
# 2  (17.947, 25.429]    16      0.16       16.0       16            16
# 5  (25.429, 32.857]    13      0.13       13.0       29            29
# 1  (32.857, 40.286]    16      0.16       16.0       45            45
# 6  (40.286, 47.714]     8      0.08        8.0       53            53
# 0  (47.714, 55.143]    18      0.18       18.0       71            71
# 3  (55.143, 62.571]    15      0.15       15.0       86            86
# 4    (62.571, 70.0]    14      0.14       14.0      100           100

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(edades,alpha=0.5)
plt.title("HISTOGRAMA DE EDADES BASADO EN LA FUNCION DE MATPLOTLIP CON VALORES ESTANDAR")
# Out:
# Text(0.5, 1.0, 'HISTOGRAMA DE EDADES BASADO EN LA FUNCION DE MATPLOTLIP CON VALORES ESTANDAR')

# %%
#crear histograma basado en la tabla de frecuencia
plt.hist(df['edad'],bins=K,alpha=0.5)
plt.title("HISTOGRAMA DE EDADES BASADO EN LA REGLA DE STURGES ")
plt.xlabel('edades')
plt.ylabel('frecuencia')
plt.text(0,0.5,'frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# <a href="https://colab.research.google.com/github/25040150-source/PROBABILIDAD-Y-ESTADISTICA/blob/main/UNIDAD%203/probabilidad_U3_ejercicio1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Probabilidad y estadistica 2Y
# ##Unidad 3.- variables aleatorias
# ###EJERCICIO 1
# ###Maestro: José Gabriel Rodriguez Rivas
# ###Alumno: Marcela Pérez Gurrola

# %% [markdown]
# Un investigador biomedico realiza un conteo del numero de celulas anormales observadas en una muestra de tejido tomada de distintos pacientes.
# la variable aleatoria X representa el numero de celulas anormales encontradas en una muestra seleccionada al azar de una lamina. a partir de observaciones previas, se estima la siguiente distribucion de probabilidad:
#
# #num de celulas anormales (X)  [0,1,2,3,4,5]
# #probabilidad P(X) [0.10,0.25,0.30,0.20,0.10,0.05]
#
# 1.-verifique que las probabilidades sumen 1.
#
# 2.-elabore la distribucion de probabilidad X.
#
# 3.-Calcule:
#
# *el valor esperado E(X) (promedio de celulas anormales por muestra).
#
# *la varianza y la desviacion estandar.
#
# 4.-construya la funcion de distribucion acumulada F(X) y representala graficamente.
#
# 5.-interprete los resultados en el contexto biomedico:
#
# ¿cual es promedio esperado de células anormales por muestra?
#
# El promedio esperado, o valor esperado
# 𝐸(𝑋)
# E(X), es 2.10. Esto significa que en promedio se espera encontrar alrededor de 2 células anormales por muestra. En términos biomédicos, representa el número típico de células anormales que se podrían observar en una lámina seleccionada al azar.
#
# ¿existe mucha variabilidad entre las muestras?
#
# No, la variabilidad es moderada, ya que la desviación estándar es 1.30. Esto indica que la mayoría de las muestras tienen un número de células cercano al promedio (entre 1 y 3 células anormales), mientras que valores más altos como 4 o 5 son menos comunes.
#
# ¿que indica la funcion acumulada sobre la probabilidad de encontrar un número bajo o alto de células anormales?
#
# La función acumulada muestra que hay una probabilidad del 65% de encontrar 2 o menos células anormales y un 85% de encontrar 3 o menos. Esto significa que los valores bajos son mucho más probables, mientras que los valores altos (4 o 5) son poco frecuentes. En conclusión, la mayoría de las muestras presentan pocos casos de células anormales, lo que sugiere un comportamiento estable y poco riesgoso en las observaciones.

# %%
# =========================================================
# EJERCICIO 1 - Células anormales por muestra
# =========================================================

import matplotlib.pyplot as plt
import numpy as np

# Valores de la variable aleatoria
x = np.array([0, 1, 2, 3, 4, 5])
p = np.array([0.10, 0.25, 0.30, 0.20, 0.10, 0.05])

# 1. Verificar suma de probabilidades
print("Suma de probabilidades:", np.sum(p))

# 2. Calcular valor esperado
E_X = np.sum(x * p)
print("Valor esperado E(X):", E_X)

# 3. Calcular varianza y desviación estándar
E_X2 = np.sum(x**2 * p)
Var_X = E_X2 - E_X**2
Desv_X = np.sqrt(Var_X)
print("Varianza:", Var_X)
print("Desviación estándar:", Desv_X)

# 4. Función de distribución acumulada
F = np.cumsum(p)
print("Función acumulada F(x):", F)

# 5. Graficar FDA
plt.step(x, F, where='post', color='blue', label='F(x)')
plt.title("Función de Distribución Acumulada - Ejercicio 1")
plt.xlabel("Número de células anormales (X)")
plt.ylabel("Probabilidad acumulada")
plt.grid(True)
plt.legend()
plt.show()
# Out:
# Suma de probabilidades: 0.9999999999999999
# Valor esperado E(X): 2.1
# Varianza: 1.6899999999999995
# Desviación estándar: 1.2999999999999998
# Función acumulada F(x): [0.1  0.35 0.65 0.85 0.95 1.  ]
